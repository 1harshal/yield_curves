# %%
import pandas as pd

# %%
year = 2010
url = f"https://home.treasury.gov/resource-center/data-chart-center/interest-rates/TextView?type=daily_treasury_yield_curve&field_tdr_date_value={year}"
table_list = pd.read_html(url)

# %%
df = table_list[0]
df
# Out:
#            Date  20 YR  30 YR  Extrapolation Factor  8 WEEKS BANK DISCOUNT  \
# 0    01/04/2010    NaN    NaN                   NaN                    NaN
# 1    01/05/2010    NaN    NaN                   NaN                    NaN
# 2    01/06/2010    NaN    NaN                   NaN                    NaN
# 3    01/07/2010    NaN    NaN                   NaN                    NaN
# 4    01/08/2010    NaN    NaN                   NaN                    NaN
# ..          ...    ...    ...                   ...                    ...
# 247  12/27/2010    NaN    NaN                   NaN                    NaN
# 248  12/28/2010    NaN    NaN                   NaN                    NaN
# 249  12/29/2010    NaN    NaN                   NaN                    NaN
# 250  12/30/2010    NaN    NaN                   NaN                    NaN
# 251  12/31/2010    NaN    NaN                   NaN                    NaN
#
# ...

# %%
df = df.drop(['20 YR', '30 YR', 'Extrapolation Factor',
       '8 WEEKS BANK DISCOUNT', 'COUPON EQUIVALENT', '17 WEEKS BANK DISCOUNT', '52 WEEKS BANK DISCOUNT',
       'COUPON EQUIVALENT.1', 'COUPON EQUIVALENT.2'],axis=1)

# %%
df
# Out:
#            Date  1 Mo  2 Mo  3 Mo  4 Mo  6 Mo  1 Yr  2 Yr  3 Yr  5 Yr  7 Yr  \
# 0    01/04/2010  0.05   NaN  0.08   NaN  0.18  0.45  1.09  1.66  2.65  3.36
# 1    01/05/2010  0.03   NaN  0.07   NaN  0.17  0.41  1.01  1.57  2.56  3.28
# 2    01/06/2010  0.03   NaN  0.06   NaN  0.15  0.40  1.01  1.60  2.60  3.33
# 3    01/07/2010  0.02   NaN  0.05   NaN  0.16  0.40  1.03  1.62  2.62  3.33
# 4    01/08/2010  0.02   NaN  0.05   NaN  0.15  0.37  0.96  1.56  2.57  3.31
# ..          ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 247  12/27/2010  0.06   NaN  0.17   NaN  0.22  0.32  0.71  1.11  2.08  2.76
# 248  12/28/2010  0.08   NaN  0.15   NaN  0.21  0.31  0.75  1.17  2.18  2.89
# 249  12/29/2010  0.05   NaN  0.13   NaN  0.20  0.30  0.64  1.05  2.03  2.75
# 250  12/30/2010  0.05   NaN  0.12   NaN  0.20  0.29  0.66  1.07  2.06  2.76
# 251  12/31/2010  0.07   NaN  0.12   NaN  0.19  0.29  0.61  1.02  2.01  2.71
#
#      10 Yr  20 Yr  30 Yr
# 0     3.85   4.60   4.65
# ...

# %%
def clean_df(df):
#     df['Date'] = pd.to_datetime(df['Date'])
#     df = df.set_index('Date')
    df = df.drop(['20 YR', '30 YR', 'Extrapolation Factor',
       '8 WEEKS BANK DISCOUNT', 'COUPON EQUIVALENT', '17 WEEKS BANK DISCOUNT', '52 WEEKS BANK DISCOUNT',
       'COUPON EQUIVALENT.1', 'COUPON EQUIVALENT.2'],axis=1)
    return df

# %%
for year in range(2011,2023):
    url = f"https://home.treasury.gov/resource-center/data-chart-center/interest-rates/TextView?type=daily_treasury_yield_curve&field_tdr_date_value={year}"
    table_list = pd.read_html(url)
    df = pd.concat([df,clean_df(table_list[0])])

# %%
df
# Out:
#            Date  1 Mo  2 Mo  3 Mo  4 Mo  6 Mo  1 Yr  2 Yr  3 Yr  5 Yr  7 Yr  \
# 0    01/04/2010  0.05   NaN  0.08   NaN  0.18  0.45  1.09  1.66  2.65  3.36
# 1    01/05/2010  0.03   NaN  0.07   NaN  0.17  0.41  1.01  1.57  2.56  3.28
# 2    01/06/2010  0.03   NaN  0.06   NaN  0.15  0.40  1.01  1.60  2.60  3.33
# 3    01/07/2010  0.02   NaN  0.05   NaN  0.16  0.40  1.03  1.62  2.62  3.33
# 4    01/08/2010  0.02   NaN  0.05   NaN  0.15  0.37  0.96  1.56  2.57  3.31
# ..          ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 244  12/23/2022  3.80  4.20  4.34  4.59  4.67  4.66  4.31  4.09  3.86  3.83
# 245  12/27/2022  3.87  4.32  4.46  4.66  4.76  4.75  4.32  4.17  3.94  3.93
# 246  12/28/2022  3.86  4.33  4.46  4.66  4.75  4.71  4.31  4.18  3.97  3.97
# 247  12/29/2022  4.04  4.39  4.45  4.66  4.73  4.71  4.34  4.16  3.94  3.91
# 248  12/30/2022  4.12  4.41  4.42  4.69  4.76  4.73  4.41  4.22  3.99  3.96
#
#      10 Yr  20 Yr  30 Yr
# 0     3.85   4.60   4.65
# ...

# %%
df.to_excel("yields.xlsx")

# %%
df2 = df.drop(['Date'],axis=1)

# %%
df2
# Out:
#      1 Mo  2 Mo  3 Mo  4 Mo  6 Mo  1 Yr  2 Yr  3 Yr  5 Yr  7 Yr  10 Yr  20 Yr  \
# 0    0.05   NaN  0.08   NaN  0.18  0.45  1.09  1.66  2.65  3.36   3.85   4.60
# 1    0.03   NaN  0.07   NaN  0.17  0.41  1.01  1.57  2.56  3.28   3.77   4.54
# 2    0.03   NaN  0.06   NaN  0.15  0.40  1.01  1.60  2.60  3.33   3.85   4.63
# 3    0.02   NaN  0.05   NaN  0.16  0.40  1.03  1.62  2.62  3.33   3.85   4.62
# 4    0.02   NaN  0.05   NaN  0.15  0.37  0.96  1.56  2.57  3.31   3.83   4.61
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...    ...    ...
# 244  3.80  4.20  4.34  4.59  4.67  4.66  4.31  4.09  3.86  3.83   3.75   3.99
# 245  3.87  4.32  4.46  4.66  4.76  4.75  4.32  4.17  3.94  3.93   3.84   4.10
# 246  3.86  4.33  4.46  4.66  4.75  4.71  4.31  4.18  3.97  3.97   3.88   4.13
# 247  4.04  4.39  4.45  4.66  4.73  4.71  4.34  4.16  3.94  3.91   3.83   4.09
# 248  4.12  4.41  4.42  4.69  4.76  4.73  4.41  4.22  3.99  3.96   3.88   4.14
#
#      30 Yr
# 0     4.65
# ...

# %%
df2.iloc[[0]]
# Out:
#    1 Mo  2 Mo  3 Mo  4 Mo  6 Mo  1 Yr  2 Yr  3 Yr  5 Yr  7 Yr  10 Yr  20 Yr  \
# 0  0.05   NaN  0.08   NaN  0.18  0.45  1.09  1.66  2.65  3.36   3.85    4.6
#
#    30 Yr
# 0   4.65

# %%
df2
# Out:
#      1 Mo  2 Mo  3 Mo  4 Mo  6 Mo  1 Yr  2 Yr  3 Yr  5 Yr  7 Yr  10 Yr  20 Yr  \
# 0    0.05   NaN  0.08   NaN  0.18  0.45  1.09  1.66  2.65  3.36   3.85   4.60
# 1    0.03   NaN  0.07   NaN  0.17  0.41  1.01  1.57  2.56  3.28   3.77   4.54
# 2    0.03   NaN  0.06   NaN  0.15  0.40  1.01  1.60  2.60  3.33   3.85   4.63
# 3    0.02   NaN  0.05   NaN  0.16  0.40  1.03  1.62  2.62  3.33   3.85   4.62
# 4    0.02   NaN  0.05   NaN  0.15  0.37  0.96  1.56  2.57  3.31   3.83   4.61
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...    ...    ...
# 244  3.80  4.20  4.34  4.59  4.67  4.66  4.31  4.09  3.86  3.83   3.75   3.99
# 245  3.87  4.32  4.46  4.66  4.76  4.75  4.32  4.17  3.94  3.93   3.84   4.10
# 246  3.86  4.33  4.46  4.66  4.75  4.71  4.31  4.18  3.97  3.97   3.88   4.13
# 247  4.04  4.39  4.45  4.66  4.73  4.71  4.34  4.16  3.94  3.91   3.83   4.09
# 248  4.12  4.41  4.42  4.69  4.76  4.73  4.41  4.22  3.99  3.96   3.88   4.14
#
#      30 Yr
# 0     4.65
# ...

# %%
df2.drop(['2 Mo', '4 Mo'], axis=1, inplace = True)

# %%
df2
# Out:
#      1 Mo  3 Mo  6 Mo  1 Yr  2 Yr  3 Yr  5 Yr  7 Yr  10 Yr  20 Yr  30 Yr
# 0    0.05  0.08  0.18  0.45  1.09  1.66  2.65  3.36   3.85   4.60   4.65
# 1    0.03  0.07  0.17  0.41  1.01  1.57  2.56  3.28   3.77   4.54   4.59
# 2    0.03  0.06  0.15  0.40  1.01  1.60  2.60  3.33   3.85   4.63   4.70
# 3    0.02  0.05  0.16  0.40  1.03  1.62  2.62  3.33   3.85   4.62   4.69
# 4    0.02  0.05  0.15  0.37  0.96  1.56  2.57  3.31   3.83   4.61   4.70
# ..    ...   ...   ...   ...   ...   ...   ...   ...    ...    ...    ...
# 244  3.80  4.34  4.67  4.66  4.31  4.09  3.86  3.83   3.75   3.99   3.82
# 245  3.87  4.46  4.76  4.75  4.32  4.17  3.94  3.93   3.84   4.10   3.93
# 246  3.86  4.46  4.75  4.71  4.31  4.18  3.97  3.97   3.88   4.13   3.98
# 247  4.04  4.45  4.73  4.71  4.34  4.16  3.94  3.91   3.83   4.09   3.92
# 248  4.12  4.42  4.76  4.73  4.41  4.22  3.99  3.96   3.88   4.14   3.97
#
# [3253 rows x 11 columns]

# %%
import seaborn as sns

# %%
sns.heatmap(df2)
# Out:
# <AxesSubplot:>

# %%
import plotly.graph_objects as go
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df2.iloc[[0]]
# Out:
#    1 Mo  3 Mo  6 Mo  1 Yr  2 Yr  3 Yr  5 Yr  7 Yr  10 Yr  20 Yr  30 Yr
# 0  0.05  0.08  0.18  0.45  1.09  1.66  2.65  3.36   3.85    4.6   4.65

# %%
import time
# import matplotlib.pyplot as plt

x = df2.columns.to_numpy()
y = df2.iloc[0].to_numpy()
# x = np.array[df2.columns]

# naming the x axis
plt.xlabel('tenors')
# naming the y axis
plt.ylabel('yields')
# giving a title to my graph
plt.title('yield_curve')
    
i = 0
plt.ion()

figure, ax = plt.subplots(figsize=(10, 8))
# for i in range(3250):
#     y = df2.iloc[i].to_numpy()
#     plt.plot(x, y)
    
#     # function to show the plot
#     plt.ion()
    
for i in range(3250):
    # creating new Y values
    y = df2.iloc[i].to_numpy()
 
    # updating data values
    #line1.set_xdata(x)
    #line1.set_ydata(new_y)
 
    # drawing updated values
    figure.canvas.draw()
 
    # This will run the GUI event
    # loop until all UI events
    # currently waiting have been processed
    figure.canvas.flush_events()
 
    time.sleep(0.01)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Assuming you have imported the necessary data and created df2

x = df2.columns.to_numpy()
y = df2.iloc[0].to_numpy()

plt.ion()
fig = plt.figure()
ax = fig.add_subplot(111)
line1, = ax.plot(x, y, 'b-')

for i in range(3250):
    line1.set_ydata(df2.iloc[i].to_numpy())
    fig.canvas.draw()
    fig.canvas.flush_events()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import time

# Assuming you have a DataFrame df2 with appropriate data

x = df2.columns.to_numpy()
y = df2.iloc[0].to_numpy()

# to run GUI event loop
plt.ion()

# here we are creating subplots
figure, ax = plt.subplots(figsize=(10, 8))
line1, = ax.plot(x, y)

# setting title
plt.title("Geeks For Geeks", fontsize=20)

# setting x-axis label and y-axis label
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

# Loop
for i in range(1, 50):
    # creating new Y values
    new_y = df2.iloc[i].to_numpy()

    # updating data values
    line1.set_ydata(new_y)

    # drawing updated values
    figure.canvas.draw()

    # This will run the GUI event loop until all UI events currently waiting have been processed
    plt.pause(0.1)

plt.ioff()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import time

# Assuming you have imported the necessary data and created df2

x = df2.columns.to_numpy()
y = df2.iloc[0].to_numpy()

plt.ion()
fig = plt.figure()
ax = fig.add_subplot(111)
line1, = ax.plot(x, y, 'b-')

for i in range(3250):
    line1.set_ydata(df2.iloc[i].to_numpy())
    fig.canvas.draw()
    fig.canvas.flush_events()
    plt.pause(0.001)  # Add a slight delay to allow the plot to update
    time.sleep(0.01)  # Pause to create a visible animation effect
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 8>()
#       4 import time
#       6 # Assuming you have imported the necessary data and created df2
# ----> 8 x = df2.columns.to_numpy()
#       9 y = df2.iloc[0].to_numpy()
#      11 plt.ion()
#
# NameError: name 'df2' is not defined
